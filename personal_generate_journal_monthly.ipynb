# %%
weeklyEntries = """

"""

# %%
from app.graphql_gen.genos_utils import call_genos_api
from datetime import datetime
today = datetime.today().strftime("%B %d, %Y")

# %%
system_content = f"""
Today's date is {today}.

You are an expert content creator, moderator, and curator of text content, in particular of blog entries representing an individual's personal journal.

Generate a monthly summary journal entry that encapsulates the highlights of the weekly summaries for the last few weeks.

Assume a tone and voice that is friendly and easy to understand, and in particular, matches that of the weekly summary journal entries. Make it personal and enjoyable to read. 

Output the monthly summary in the same format as is present in each of the weekly summary entries, which is to say in a list point form with two sections, one for home and one for work. Include no more than about 16 to 20 bullet points for the home section, and no more than about 10 to 12 points for the work section. The points should be in order in each section from least recent first to most recent last, and the points should be written in complete sentences. For moments of particular import, add a social media hashtag after the sentence. The points should not begin with a bullet or a dash.

Include a header indicating the month to which the entry pertains, in this format: `yyyy-mm`.
Also, just under the date range, indicate that the text was written by an LLM (and include which LLM you are), in this format: `Summary generated by [LLM name]`

Output should be in the following format. 

````
Home
Point 1.
Point 2. #hashtag
Point 3.

Work
Point 1.
Point 2.
````


Only create the entry with no additional reasoning or text. 
"""

# %%
user_content = f"""


# !!!!!!!!!! weekly entries !!!!!!!!!!
{weeklyEntries}
# !!!!!!!!!!

"""

# %%
result = call_genos_api(system_content=system_content, user_content=user_content)
print(result)
