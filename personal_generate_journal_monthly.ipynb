# %%
weeklyEntries = """


Monday, March 31, 2025
2025-03-24 - 2025-03-30


	•	Home
	•	Put ourselves on the waitlist to get a new doctor.
	•	Lukas has spent a LOT of time this week on a big physics project. I've been helping where I can, as has Katrina. He also did study groups and had friends over to help each other out.
	•	Katrina, Lukas, and Annaliess went to the local pet shelter a bunch of times for volunteer training. Mclarens watched the kids.
	•	Katrina went to Cranbrook for a doctor's appointment.
	•	Weather is getting warm. Kids and I are spending time on the deck and trampoline, and on the OneWheels and scooters.
	•	I had a couple days where my stomach was doing somersaults and I felt quite awful.
	•	Family finished the Book of Mormon this week in our family scripture study.
	•	Lukas and the small foster three stayed home (fosters with Mclarens) while the rest of us went to Calgary for the weekend to spend a lot of money on horse stuff and then for Annaliess and Savannah to go to the Calgary youth dance, where they both had a fantastic time.
	•	In Calgary, there was an outdoor hot tub. Ellen and I spent some time in it. It had just snowed. We threw snowballs at each other. Also, the hotel had a fantastic breakfast, and we got to eat at Harvey's :)
	•	The actual driving was uneventful, save for that it was snowing a lot in Calgary and so traffic was backed way up.
	•	I taught singing time on Sunday. Afternoon weather was beautiful and we spent the time outdoors.
	•	Work
	•	I've been moved to help out with the search->ceres effort. Working mostly on contact name resolution feature.
	•	Lots of catching up after vacation, of course.
	•	Added ondemand kafka tooling.
	•	Still following up on data extractions, and related concerns.
	•	Met with the legal team about a patent our team is filing, and on which my name has been added.
	•	Had genAI resolve some TODOs in my code.


Posted by Tinclon at 5:34 PM No comments: ￼ 


Sunday, March 23, 2025
2025-03-17 - 2025-03-23


	•	Home
	•	Vacation week in Hawai'i. Amazing week. See the daily events, of course. But here's some highlights.
	•	
	•	Monday we went to the Polynesian Cultural Center. Definitely one of the big highlights of the trip. Watching the various songs, dances, and chants of the various cultures of the polynesian islands was super entertaining. I was most attracted to the Huka and the Hula. Very expressive dances.
	•	We got to try out a few cultural things as well. Fire making. Stick games. Leaf weaving.
	•	A fantastic supper, followed by the Hā: Breath of Life presentation.
	•	
	•	Tuesday we had planned kayaking, but it was quite a distance away, and on the leeward (ie. rainy) side of the island. So we went hiking instead. Jodi and Savannah stayed back. Savannah learned to make leis. 
	•	The rest of us went up Koko head canyon, and then Judd trail and Ginger pond. The Koko head was a very straight, very steep rail-line. Neither Katrina nor I was sure we were going to make it, but make it all the way to the top we did. Fantastic views.
	•	Judd trail was a complete jungle. Path covered in roots. Ended with Ginger Pond - a little freshwater pool in which we swam for a short while. Super unique experience.
	•	
	•	Wednesday we visited Pearl Harbor and the Arizona memorial. Enjoyed the little videos, and all museums. Learned some history.
	•	Then spent the afternoon lazing on the beach. Finished the day with a night swim in the ocean.
	•	
	•	Thursday we walked to the harbour and spent some of the morning parasailing. It was super neat. Much calmer experience than I would have expected. Even gaining and losing a significant amount of altitude didn't "feel" like we were moving a lot. Much less, even, than the elevator in the hotel. Got to see a whale surfacing from far above.
	•	In the afternoon we rented surfboards. That was a disaster. The kids managed to get up just a little bit, but mostly they either fell, or just couldn't "catch" any waves (we couldn't figure out how to catch them, just kept floating over them). As for me, I couldn't even lay on the board long enough for the wave to approach me. I was already back in the water.
	•	Swam a lot this afternoon. The water was warm. The air was warm. It was fabulous.
	•	One last ocean night swim.
	•	
	•	Friday was a flight and then a hotel.
	•	
	•	Saturday was a long drive.
	•	
	•	Sunday the Lowry's were in town, and there was a "snack & chat" after church and I got to talk to Melina for awhile. We picked up Rebel.
	•	At suppertime, I took Lukas to the first instalment of an emotional resiliency class he's enrolled in.


Posted by Tinclon at 9:39 PM No comments: ￼ 


2025-03-10 - 2025-03-16


	•	Home
	•	Signed up kids for next round of swimming lessons.
	•	Moreton's came over to get a lay of the land.
	•	Lots and lots of deeper cleaning in the house to get it ready for both a visit with the social worker, and for Moreton's to be here watching kids while we're gone.
	•	Davina puked in the Expedition. Even more cleaning to do.
	•	Annaliess saw her horse as much as possible.
	•	And then we left. Sarah Moreton came over. We loaded up the car, and we were on our way.
	•	Stopped at the Mongolian BBQ for lunch, and Flat Iron Grill for supper. Nice restaurants.
	•	Trip took an extra hour due to heavy snow/slush and a few accidents in the snoqualmie pass. What a pain.
	•	Got all the kids signed up for FSY.
	•	Made the flight. Watched lots of movies. Met our driver without too much issue in Hawaii.
	•	Went straight to the beach and swam. Water was big pool temperature. Cool, but nice, especially in the warm sun.
	•	I managed to touch a sharp sea-urchin on my first evening. Got some painful slivers in my finger. That was a downer.
	•	Had a bit of a fiasco connecting Jodi to her driver when her flight landed. Got it sorted while eating at a nice Mexican restaurant. Kids were surprised and happy to see her.
	•	And then our vacation really started. Up early a bunch of days for tours and activities.
	•	We went scuba diving - two dives. Had a fantastic time. So much easier to dive in warmer waters without thick wetsuits. Saw lots of fish and turtles and some eels and beige coral.
	•	Swam in the ocean a bunch. Swam in the hotel pool a lot.
	•	Watched an open-air luau across the street from our hotel room, up on the 31st floor.
	•	Went on a sight-seeing trip around the entire island. Saw a few very nice vistas, and unfortunately a lot of gift shops. Got some alright food from a food truck. Cold, though. Went snorkelling and love, love, loved it! Learned a lot from a fantastic tour guide. Lots of Hawaiian history. Saw the temple as we drove by. Had very good (and very expensive) Chinese food. All food here is crazy pricey.
	•	Work
	•	Started reducing node count on our opensearch cluster. 
	•	Had an almost-incident with the new live config stuff. Applied settings to the wrong deployments. Luckily it didn't affect our main deployment. Just a scare.
	•	Turned on txn completeness. One minor hiccup. Otherwise it went well.
	•	And then started so many extractions again.
	•	Crazy busy days trying to get everything in order before leaving on vacation.
	•	Got address code fixed in monolith, with tests and feature flags, merged.
	•	Set my status to OOO a day early, and just responded to the constant incoming flood of Slack messages.


Posted by Tinclon at 4:41 AM No comments: ￼ 


Sunday, March 9, 2025
2025-03-03 - 2025-03-09


	•	Home
	•	Annaliess has been seeing her horse as much as possible lately, now that the weather has finally turned.
	•	Helped Lukas quite a bit with derivatives homework.
	•	Ellen spent most of the week after school and a lot during school practicing for, and then being in the Lion King presentation. Katrina took Rose one of the days, and I took Annaliess the next.
	•	I collated documents for filing taxes, and then got most of it done this week. Annaliess did Talitha's with some help from me.
	•	We're doing lots of deeper cleaning to make the house prepared for our trip away.
	•	Kids got vaccinated.
	•	I took some samples to the lab, per doctor's orders.
	•	Savannah has been pretty sick, but the rest of us are starting to feel a lot better.
	•	Lukas and Annaliess both spent a night and a day in Trail for the youth dance and activity.
	•	I swept and cleaned the garage. Spring cleaning. Also washed the car.
	•	Took the kids to their final swimming lessons. They all passed.
	•	We hosted a birthday party for Chantille. A bunch of kids came. The next day she went to a birthday party.
	•	Work
	•	Lots of post-vacation catch up, and then it started as actually a bit of a slower week, which was super nice.
	•	Lots of extractions happening. Addresses, contacts, departments. Transactions and Sales taxes are coming up.
	•	Did training. Submitted p-card expenses. Wrote feedback for Vishal. 
	•	Wrote some code to add headers to our published messages.
	•	State of the company meeting.
	•	Turned on the new fields for transactions. Caused a mini incident because dynamic indices were created wrong. I figured it might happen. Bother.
	•	We're getting a lot of flack about our expenses.
	•	Upgraded our extraction service to look for all entity adjacencies.
	•	Team had a baby shower for ally.


Posted by Tinclon at 5:28 PM No comments: ￼ 


"""

# %%
from app.graphql_gen.genos_utils import call_genos_api
from datetime import datetime
today = datetime.today().strftime("%B %d, %Y")

# %%
system_content = f"""
Today's date is {today}.

You are an expert content creator, moderator, and curator of text content, in particular of blog entries representing an individual's personal journal.

Generate a monthly summary journal entry that encapsulates the highlights of the weekly summaries for the last few weeks.

Assume a tone and voice that is friendly and easy to understand, and in particular, matches that of the weekly summary journal entries. Make it personal and enjoyable to read. 

Output the monthly summary in the same format as is present in each of the weekly summary entries, which is to say in a list point form with two sections, one for home and one for work. Include no more than about 16 to 20 bullet points for the home section, and no more than about 10 to 12 points for the work section. The points should be in order in each section from least recent first to most recent last, and the points should be written in complete sentences. For moments of particular import, add a social media hashtag after the sentence. The points should not begin with a bullet or a dash.

Include a header indicating the month to which the entry pertains, in this format: `yyyy-mm`.
Also, just under the date range, indicate that the text was written by an LLM (and include which LLM you are), in this format: `Summary generated by [LLM name]`

Output should be in the following format. 

````
Home
Point 1.
Point 2. #hashtag
Point 3.

Work
Point 1.
Point 2.
````


Only create the entry with no additional reasoning or text. 
"""

# %%
user_content = f"""


# !!!!!!!!!! weekly entries !!!!!!!!!!
{weeklyEntries}
# !!!!!!!!!!

"""

# %%
result = call_genos_api(system_content=system_content, user_content=user_content)
print(result)
# Out:
# Making API call to model: gpt-4o-2024-08-06...
# 2025-03
# Summary generated by OpenAI's GPT-3
#
# Home
# Annaliess has been spending a lot of time with her horse now that the weather is improving.
# I helped Lukas with his derivatives homework, which was quite a challenge.
# Ellen was busy with the Lion King presentation, and we all took turns attending.
# I managed to get most of our taxes done, with Annaliess helping Talitha with hers.
# We did a lot of deep cleaning to prepare the house for our upcoming trip.
# The kids got their vaccinations, and I took some samples to the lab as per doctor's orders.
# Savannah was quite sick, but thankfully the rest of us are feeling better.
# Lukas and Annaliess enjoyed a youth dance and activity in Trail.
# We completed our spring cleaning by sweeping the garage and washing the car.
# The kids passed their final swimming lessons, which was a relief.
# We hosted a birthday party for Chantille, which was a lot of fun.
# ...
